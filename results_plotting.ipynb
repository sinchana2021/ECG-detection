# %%
# Baseline GRU
import re
import numpy as np

string = '''Epoch 1, Training Loss: 0.9479, Testing Loss: 0.8692
Epoch 2, Training Loss: 0.7521, Testing Loss: 0.7730
Epoch 3, Training Loss: 0.6588, Testing Loss: 0.7323
Epoch 4, Training Loss: 0.6013, Testing Loss: 0.7391
Epoch 5, Training Loss: 0.5554, Testing Loss: 0.7730
Epoch 6, Training Loss: 0.5112, Testing Loss: 0.7864
Epoch 7, Training Loss: 0.4607, Testing Loss: 0.8671
Epoch 8, Training Loss: 0.4198, Testing Loss: 0.8741
Epoch 9, Training Loss: 0.3763, Testing Loss: 0.9112
Epoch 10, Training Loss: 0.3370, Testing Loss: 1.0242
Epoch 11, Training Loss: 0.2952, Testing Loss: 1.0776
Epoch 12, Training Loss: 0.2572, Testing Loss: 1.1853
Epoch 13, Training Loss: 0.2225, Testing Loss: 1.3398
Epoch 14, Training Loss: 0.1886, Testing Loss: 1.4837
Epoch 15, Training Loss: 0.1632, Testing Loss: 1.4936
Epoch 16, Training Loss: 0.1368, Testing Loss: 1.7467
Epoch 17, Training Loss: 0.1181, Testing Loss: 1.8053
Epoch 18, Training Loss: 0.1003, Testing Loss: 1.8906
Epoch 19, Training Loss: 0.0811, Testing Loss: 1.9618
Epoch 20, Training Loss: 0.0629, Testing Loss: 2.0774
Epoch 21, Training Loss: 0.0542, Testing Loss: 2.2116
Epoch 22, Training Loss: 0.0501, Testing Loss: 2.2778
Epoch 23, Training Loss: 0.0513, Testing Loss: 2.3316
Epoch 24, Training Loss: 0.0506, Testing Loss: 2.3490
Epoch 25, Training Loss: 0.0398, Testing Loss: 2.4954
Epoch 26, Training Loss: 0.0312, Testing Loss: 2.6266
Epoch 27, Training Loss: 0.0189, Testing Loss: 2.7213
Epoch 28, Training Loss: 0.0188, Testing Loss: 2.7702
Epoch 29, Training Loss: 0.0255, Testing Loss: 3.0320
Epoch 30, Training Loss: 0.0658, Testing Loss: 2.7564'''
lines = string.split('\n')
parts = [line.split(',') for line in lines]
for i, line in enumerate(parts):
    for j, part in enumerate(line):
        parts[i][j] = float(re.sub(r"[^0-9.]", "", part))

parts = np.array(parts).T
print(parts[1])  # train loss
print(parts[2])  # test loss
# Out:
# [0.9479 0.7521 0.6588 0.6013 0.5554 0.5112 0.4607 0.4198 0.3763 0.337
#  0.2952 0.2572 0.2225 0.1886 0.1632 0.1368 0.1181 0.1003 0.0811 0.0629
#  0.0542 0.0501 0.0513 0.0506 0.0398 0.0312 0.0189 0.0188 0.0255 0.0658]
# [0.8692 0.773  0.7323 0.7391 0.773  0.7864 0.8671 0.8741 0.9112 1.0242
#  1.0776 1.1853 1.3398 1.4837 1.4936 1.7467 1.8053 1.8906 1.9618 2.0774
#  2.2116 2.2778 2.3316 2.349  2.4954 2.6266 2.7213 2.7702 3.032  2.7564]

# %%
# Refined GRU
import re
import numpy as np

string = '''Epoch 1, Training Loss: 0.8010, Testing Loss: 0.7084
Epoch 2, Training Loss: 0.6244, Testing Loss: 0.6521
Epoch 3, Training Loss: 0.5730, Testing Loss: 0.6044
Epoch 4, Training Loss: 0.5405, Testing Loss: 0.6011
Epoch 5, Training Loss: 0.5132, Testing Loss: 0.5759
Epoch 6, Training Loss: 0.4974, Testing Loss: 0.5798
Epoch 7, Training Loss: 0.4815, Testing Loss: 0.5417
Epoch 8, Training Loss: 0.4677, Testing Loss: 0.5360
Epoch 9, Training Loss: 0.4522, Testing Loss: 0.5323
Epoch 10, Training Loss: 0.4382, Testing Loss: 0.5312
Epoch 11, Training Loss: 0.4243, Testing Loss: 0.5410
Epoch 12, Training Loss: 0.4120, Testing Loss: 0.5487
Epoch 13, Training Loss: 0.3997, Testing Loss: 0.5608
Epoch 14, Training Loss: 0.3879, Testing Loss: 0.6122
Epoch 15, Training Loss: 0.3780, Testing Loss: 0.5655
Epoch 16, Training Loss: 0.3593, Testing Loss: 0.5751
Epoch 17, Training Loss: 0.3489, Testing Loss: 0.5798
Epoch 18, Training Loss: 0.3314, Testing Loss: 0.5802
Epoch 19, Training Loss: 0.3178, Testing Loss: 0.6276
Epoch 20, Training Loss: 0.3060, Testing Loss: 0.6602
Epoch 21, Training Loss: 0.2895, Testing Loss: 0.6832
Epoch 22, Training Loss: 0.2770, Testing Loss: 0.6938
Epoch 23, Training Loss: 0.2660, Testing Loss: 0.6931
Epoch 24, Training Loss: 0.2534, Testing Loss: 0.7164
Epoch 25, Training Loss: 0.2387, Testing Loss: 0.8171
Epoch 26, Training Loss: 0.2278, Testing Loss: 0.7502
Epoch 27, Training Loss: 0.2164, Testing Loss: 0.8363
Epoch 28, Training Loss: 0.2166, Testing Loss: 0.8451
Epoch 29, Training Loss: 0.1934, Testing Loss: 0.8659
Epoch 30, Training Loss: 0.1889, Testing Loss: 0.8313'''
lines = string.split('\n')
parts = [line.split(',') for line in lines]
for i, line in enumerate(parts):
    for j, part in enumerate(line):
        parts[i][j] = float(re.sub(r"[^0-9.]", "", part))

parts = np.array(parts).T
print(parts[2])
# Out:
# [0.7084 0.6521 0.6044 0.6011 0.5759 0.5798 0.5417 0.536  0.5323 0.5312
#  0.541  0.5487 0.5608 0.6122 0.5655 0.5751 0.5798 0.5802 0.6276 0.6602
#  0.6832 0.6938 0.6931 0.7164 0.8171 0.7502 0.8363 0.8451 0.8659 0.8313]

# %%
# CNN-GRU
import re
import numpy as np

string = '''Epoch 1, Training Loss: 0.9187, Testing Loss: 0.8139
Epoch 2, Training Loss: 0.7566, Testing Loss: 0.7446
Epoch 3, Training Loss: 0.6891, Testing Loss: 0.6951
Epoch 4, Training Loss: 0.6519, Testing Loss: 0.6749
Epoch 5, Training Loss: 0.6291, Testing Loss: 0.6520
Epoch 6, Training Loss: 0.6124, Testing Loss: 0.6388
Epoch 7, Training Loss: 0.5994, Testing Loss: 0.6309
Epoch 8, Training Loss: 0.5859, Testing Loss: 0.6368
Epoch 9, Training Loss: 0.5766, Testing Loss: 0.6089
Epoch 10, Training Loss: 0.5670, Testing Loss: 0.6211
Epoch 11, Training Loss: 0.5589, Testing Loss: 0.6259
Epoch 12, Training Loss: 0.5506, Testing Loss: 0.5922
Epoch 13, Training Loss: 0.5443, Testing Loss: 0.5923
Epoch 14, Training Loss: 0.5375, Testing Loss: 0.6046
Epoch 15, Training Loss: 0.5322, Testing Loss: 0.6034
Epoch 16, Training Loss: 0.5234, Testing Loss: 0.5923
Epoch 17, Training Loss: 0.5195, Testing Loss: 0.5895
Epoch 18, Training Loss: 0.5170, Testing Loss: 0.5822
Epoch 19, Training Loss: 0.5127, Testing Loss: 0.6045
Epoch 20, Training Loss: 0.5096, Testing Loss: 0.5818
Epoch 21, Training Loss: 0.5063, Testing Loss: 0.5851
Epoch 22, Training Loss: 0.5025, Testing Loss: 0.5768
Epoch 23, Training Loss: 0.5005, Testing Loss: 0.5743
Epoch 24, Training Loss: 0.4977, Testing Loss: 0.5710
Epoch 25, Training Loss: 0.4917, Testing Loss: 0.5727
Epoch 26, Training Loss: 0.4900, Testing Loss: 0.5665
Epoch 27, Training Loss: 0.4857, Testing Loss: 0.5700
Epoch 28, Training Loss: 0.4826, Testing Loss: 0.5717
Epoch 29, Training Loss: 0.4812, Testing Loss: 0.5719
Epoch 30, Training Loss: 0.4780, Testing Loss: 0.5882'''
lines = string.split('\n')
parts = [line.split(',') for line in lines]
for i, line in enumerate(parts):
    for j, part in enumerate(line):
        parts[i][j] = float(re.sub(r"[^0-9.]", "", part))

parts = np.array(parts).T
print(parts[1])
# Out:
# [0.9187 0.7566 0.6891 0.6519 0.6291 0.6124 0.5994 0.5859 0.5766 0.567
#  0.5589 0.5506 0.5443 0.5375 0.5322 0.5234 0.5195 0.517  0.5127 0.5096
#  0.5063 0.5025 0.5005 0.4977 0.4917 0.49   0.4857 0.4826 0.4812 0.478 ]

# %%
# CNN-Transformer
import re
import numpy as np

string = '''Epoch 1, Training Loss: 0.8073, Testing Loss: 0.7237
Epoch 2, Training Loss: 0.6726, Testing Loss: 0.7506
Epoch 3, Training Loss: 0.6277, Testing Loss: 0.6385
Epoch 4, Training Loss: 0.5990, Testing Loss: 0.6239
Epoch 5, Training Loss: 0.5819, Testing Loss: 0.6246
Epoch 6, Training Loss: 0.5689, Testing Loss: 0.6089
Epoch 7, Training Loss: 0.5571, Testing Loss: 0.6141
Epoch 8, Training Loss: 0.5459, Testing Loss: 0.5987
Epoch 9, Training Loss: 0.5390, Testing Loss: 0.6538
Epoch 10, Training Loss: 0.5300, Testing Loss: 0.6220
Epoch 11, Training Loss: 0.5209, Testing Loss: 0.6433
Epoch 12, Training Loss: 0.5146, Testing Loss: 0.5919
Epoch 13, Training Loss: 0.5078, Testing Loss: 0.6606
Epoch 14, Training Loss: 0.5009, Testing Loss: 0.5989
Epoch 15, Training Loss: 0.4942, Testing Loss: 0.6469
Epoch 16, Training Loss: 0.4900, Testing Loss: 0.6295
Epoch 17, Training Loss: 0.4827, Testing Loss: 0.5914
Epoch 18, Training Loss: 0.4774, Testing Loss: 0.6262
Epoch 19, Training Loss: 0.4716, Testing Loss: 0.6055
Epoch 20, Training Loss: 0.4661, Testing Loss: 0.6272'''
lines = string.split('\n')
parts = [line.split(',') for line in lines]
for i, line in enumerate(parts):
    for j, part in enumerate(line):
        parts[i][j] = float(re.sub(r"[^0-9.]", "", part))

parts = np.array(parts).T
print(parts[2])
# Out:
# [0.7237 0.7506 0.6385 0.6239 0.6246 0.6089 0.6141 0.5987 0.6538 0.622
#  0.6433 0.5919 0.6606 0.5989 0.6469 0.6295 0.5914 0.6262 0.6055 0.6272]

# %%
import matplotlib.pyplot as plt

cnn_train = [0.6887,0.5941,0.5607,0.5432,0.5302,0.5182,0.5097,0.5038,0.4945,0.4906,0.4825,0.4756,0.4744,0.4701,0.4640,0.4594,0.4545,0.4505,0.4471,0.4421,0.4380,0.4363,0.4300,0.4298,0.4246,0.4210,0.4171,0.4143,0.4115,0.4065]
cnn_test = [0.6519,0.6789,0.6100,0.5798,0.6359,0.5751,0.5814,0.5823,0.5450,0.5613,0.5552,0.6227,0.5428,0.5709,0.5539,0.5471,0.5358,0.5394,0.5576,0.5482,0.5398,0.5529,0.5340,0.5521,0.5782,0.5668,0.5571,0.5542,0.5732,0.5585]
gru_baseline_train = [0.9479, 0.7521, 0.6588, 0.6013, 0.5554, 0.5112, 0.4607, 0.4198, 0.3763, 0.337, 0.2952, 0.2572, 0.2225, 0.1886, 0.1632, 0.1368, 0.1181, 0.1003, 0.0811, 0.0629, 0.0542, 0.0501, 0.0513, 0.0506, 0.0398, 0.0312, 0.0189, 0.0188, 0.0255, 0.0658]
gru_baseline_test = [0.8692, 0.773, 0.7323, 0.7391, 0.773, 0.7864, 0.8671, 0.8741, 0.9112, 1.0242, 1.0776, 1.1853, 1.3398, 1.4837, 1.4936, 1.7467, 1.8053, 1.8906, 1.9618, 2.0774, 2.2116, 2.2778, 2.3316, 2.349, 2.4954, 2.6266, 2.7213, 2.7702, 3.032, 2.7564]
gru_refined_train = [0.801, 0.6244, 0.573, 0.5405, 0.5132, 0.4974, 0.4815, 0.4677, 0.4522, 0.4382, 0.4243, 0.412, 0.3997, 0.3879, 0.378, 0.3593, 0.3489, 0.3314, 0.3178, 0.306, 0.2895, 0.277, 0.266, 0.2534, 0.2387, 0.2278, 0.2164, 0.2166, 0.1934, 0.1889]
gru_refined_test = [0.7084, 0.6521, 0.6044, 0.6011, 0.5759, 0.5798, 0.5417, 0.536, 0.5323, 0.5312, 0.541, 0.5487, 0.5608, 0.6122, 0.5655, 0.5751, 0.5798, 0.5802, 0.6276, 0.6602, 0.6832, 0.6938, 0.6931, 0.7164, 0.8171, 0.7502, 0.8363, 0.8451, 0.8659, 0.8313]
cnn_gru_train = [0.9187, 0.7566, 0.6891, 0.6519, 0.6291, 0.6124, 0.5994, 0.5859, 0.5766, 0.567, 0.5589, 0.5506, 0.5443, 0.5375, 0.5322, 0.5234, 0.5195, 0.517, 0.5127, 0.5096, 0.5063, 0.5025, 0.5005, 0.4977, 0.4917, 0.49, 0.4857, 0.4826, 0.4812, 0.478]
cnn_gru_test = [0.8139, 0.7446, 0.6951, 0.6749, 0.652, 0.6388, 0.6309, 0.6368, 0.6089, 0.6211, 0.6259, 0.5922, 0.5923, 0.6046, 0.6034, 0.5923, 0.5895, 0.5822, 0.6045, 0.5818, 0.5851, 0.5768, 0.5743, 0.571,  0.5727, 0.5665, 0.57, 0.5717, 0.5719, 0.5882]
cnn_trans_train = [0.8073, 0.6726, 0.6277, 0.599, 0.5819, 0.5689, 0.5571, 0.5459, 0.539, 0.53, 0.5209, 0.5146, 0.5078, 0.5009, 0.4942, 0.49, 0.4827, 0.4774, 0.4716, 0.4661] + 10*[np.nan]
cnn_trans_test = [0.7237, 0.7506, 0.6385, 0.6239, 0.6246, 0.6089, 0.6141, 0.5987, 0.6538, 0.622, 0.6433, 0.5919, 0.6606, 0.5989, 0.6469, 0.6295, 0.5914, 0.6262, 0.6055, 0.6272] + 10*[np.nan]

epochs = range(1, 31)

fig, axes = plt.subplots(1, 4, figsize=(12, 4), sharey=True)

axes[0].plot(epochs, cnn_train, label='Train', color='#3266ad')
axes[0].plot(epochs, cnn_test, label='Test', color='#3266ad', linestyle='--', alpha=0.6)
axes[0].set_title('CNN training curves')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()

axes[1].plot(epochs, gru_refined_train, label='Train', color='#9CE0E0')
axes[1].plot(epochs, gru_refined_test, label='Test', color='#9CE0E0', linestyle='--', alpha=0.6)
axes[1].set_title('Refined GRU training curves')
axes[1].set_xlabel('Epoch')
axes[1].legend()

axes[2].plot(epochs, cnn_gru_train, label='Train', color="#9A258E")
axes[2].plot(epochs, cnn_gru_test, label='Test', color='#9A258E', linestyle='--', alpha=0.6)
axes[2].set_title('CNN-GRU training curves')
axes[2].set_xlabel('Epoch')
axes[2].legend()

axes[3].plot(epochs, cnn_trans_train, label='Train', color="#D78E19")
axes[3].plot(epochs, cnn_trans_test, label='Test', color='#D78E19', linestyle='--', alpha=0.6)
axes[3].set_title('CNN-Transformer training curves')
axes[3].set_xlabel('Epoch')
axes[3].legend()

plt.tight_layout()
plt.savefig('training_curves.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = ['CD', 'HYP', 'MI', 'NORM', 'STTC']

metrics = {
'F1-score': {
'CNN': [0.727, 0.571, 0.738, 0.849, 0.741],
'GRU-Baseline': [0.581, 0.510, 0.576, 0.791, 0.660],
'GRU-Refined': [0.724, 0.536, 0.755, 0.852, 0.753],
'CNN-GRU': [0.725, 0.532, 0.697, 0.836, 0.719],
'CNN-Trans': [0.676, 0.492, 0.690, 0.833, 0.680]
},
'AUROC': {
'CNN': [0.833, 0.810, 0.834, 0.863, 0.857],
'GRU-Baseline': [0.742, 0.766, 0.738, 0.806, 0.807],
'GRU-Refined': [0.843, 0.822, 0.845, 0.866, 0.862],
'CNN-GRU': [0.840, 0.808, 0.819, 0.854, 0.850],
'CNN-Trans': [0.813, 0.803, 0.809, 0.850, 0.836]
},
'Accuracy': {
'CNN': [0.870, 0.869, 0.861, 0.854, 0.858],
'GRU-Baseline': [0.782, 0.850, 0.699, 0.797, 0.798],
'GRU-Refined': [0.860, 0.834, 0.872, 0.857, 0.867],
'CNN-GRU': [0.864, 0.839, 0.824, 0.854, 0.838],
'CNN-Trans': [0.831, 0.802, 0.825, 0.849, 0.797]
}
}

# %%
# looking at CNN vs Baseline GRU
x = np.arange(len(classes))
width = 0.35

fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=False)

for ax, (metric_name, vals) in zip(axes, metrics.items()):
    ax.bar(x - width/2, vals['CNN'], width, label='CNN', color='#3266ad')
    ax.bar(x + width/2, vals['GRU-Baseline'], width, label='Baseline GRU', color="#1D9E75")
    ax.set_title(metric_name)
    ax.set_xticks(x)
    ax.set_xticklabels(classes)
    ax.set_ylim(0, 1)
    ax.set_ylabel(metric_name)
    ax.legend(
        loc='upper center',         # Anchor point of the legend is its upper center
        bbox_to_anchor=(0.5, 1),  # Coordinates relative to the axes (0.5=center, 1.1=just above the top of the plot)
        ncol=2,                     # Number of columns (3 items = 1 horizontal row)
        fancybox=True,              # Optional: adds a nice background box
        shadow=True,                 # Optional: adds a shadow
        fontsize='x-small'
    )

plt.suptitle('CNN vs. Baseline GRU — per class comparison', fontsize=13)
plt.tight_layout()
plt.savefig('CNN_v_baseline_GRU_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# looking at GRU refining
x = np.arange(len(classes))
width = 0.35

fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=False)

for ax, (metric_name, vals) in zip(axes, metrics.items()):
    ax.bar(x - width/2, vals['GRU-Baseline'], width, label='Baseline GRU', color='#1D9E75')
    ax.bar(x + width/2, vals['GRU-Refined'], width, label='Refined GRU', color="#9CE0E0")
    ax.set_title(metric_name)
    ax.set_xticks(x)
    ax.set_xticklabels(classes)
    ax.set_ylim(0, 1)
    ax.set_ylabel(metric_name)
    ax.legend(
        loc='upper center',         # Anchor point of the legend is its upper center
        bbox_to_anchor=(0.5, 1),  # Coordinates relative to the axes (0.5=center, 1.1=just above the top of the plot)
        ncol=2,                     # Number of columns (3 items = 1 horizontal row)
        fancybox=True,              # Optional: adds a nice background box
        shadow=True,                 # Optional: adds a shadow
        fontsize='x-small'
    )

plt.suptitle('Baseline vs. Refined GRU — per class comparison', fontsize=13)
plt.tight_layout()
plt.savefig('GRU_refining_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# view all models (using refined gru not basleine)
x = np.arange(len(classes))
width = 0.175

fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=False)

for ax, (metric_name, vals) in zip(axes, metrics.items()):
    ax.bar(x - 3*width/2, vals['CNN'], width, label='CNN', color='#3266ad')
    ax.bar(x - width/2, vals['GRU-Refined'], width, label='Refined GRU', color='#9CE0E0')
    ax.bar(x + width/2, vals['CNN-GRU'], width, label='CNN-GRU', color='#9A258E')
    ax.bar(x + 3*width/2, vals['CNN-Trans'], width, label='CNN-Trans', color='#D78E19')
    ax.set_title(metric_name)
    ax.set_xticks(x)
    ax.set_xticklabels(classes)
    ax.set_ylim(0, 1)
    ax.set_ylabel(metric_name)
    ax.legend(
        loc='upper center',         # Anchor point of the legend is its upper center
        bbox_to_anchor=(0.5, 1),  # Coordinates relative to the axes (0.5=center, 1.1=just above the top of the plot)
        ncol=4,                     # Number of columns (3 items = 1 horizontal row)
        fancybox=True,              # Optional: adds a nice background box
        shadow=True,                 # Optional: adds a shadow
        fontsize='x-small'
    )

plt.suptitle('Models — per class comparison', fontsize=13)
plt.tight_layout()
plt.savefig('model_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
for model_name, model_scores in metrics['Accuracy'].items():
    print(f'{model_name} Mean Accuracy: {np.mean(model_scores):.3f}')
# Out:
# CNN Mean Accuracy: 0.862
# GRU-Baseline Mean Accuracy: 0.785
# GRU-Refined Mean Accuracy: 0.858
# CNN-GRU Mean Accuracy: 0.844
# CNN-Trans Mean Accuracy: 0.821

# %%
for model_name, model_scores in metrics['F1-score'].items():
    print(f'{model_name} Macro F1: {np.mean(model_scores):.3f}')
# Out:
# CNN Macro F1: 0.725
# GRU-Baseline Macro F1: 0.624
# GRU-Refined Macro F1: 0.724
# CNN-GRU Macro F1: 0.702
# CNN-Trans Macro F1: 0.674

# %%
for model_name, model_scores in metrics['AUROC'].items():
    print(f'{model_name} Macro AUROC: {np.mean(model_scores):.3f}')
# Out:
# CNN Macro AUROC: 0.839
# GRU-Baseline Macro AUROC: 0.772
# GRU-Refined Macro AUROC: 0.848
# CNN-GRU Macro AUROC: 0.834
# CNN-Trans Macro AUROC: 0.822
